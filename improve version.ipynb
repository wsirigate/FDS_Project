# %% [markdown]
# ## Import library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import data

# %%
df = pd.read_excel("หนี้สินเฉลี่ยต่อครัวเรือน จำแนกตามวัตถุประสงค์ของการกู้ยืม เป็นรายจังหวัด_พ.ศ._2545-2560_edit.xlsx")

# %%
df.head(10)
# Out:
#        ภาค        จังหวัด            วัตถุประสงค์ของการกู้ยืม       2545  \
# 0  ภาคกลาง  กรุงเทพมหานคร                     หนี้สินทั้งสิ้น  162199.23
# 1  ภาคกลาง  กรุงเทพมหานคร             เพื่อใช้จ่ายในครัวเรือน  117724.88
# 2  ภาคกลาง  กรุงเทพมหานคร   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร   44118.82
# 3  ภาคกลาง  กรุงเทพมหานคร                  เพื่อใช้ทำการเกษตร      85.69
# 4  ภาคกลาง  กรุงเทพมหานคร                  เพื่อใช้ในการศึกษา       0.00
# 5  ภาคกลาง  กรุงเทพมหานคร  เพื่อใช้ซื้อ/เช่าซื้อบ้านและที่ดิน       0.00
# 6  ภาคกลาง  กรุงเทพมหานคร                              อื่น ๆ     269.82
# 7  ภาคกลาง    สมุทรปราการ                     หนี้สินทั้งสิ้น   84345.14
# 8  ภาคกลาง    สมุทรปราการ             เพื่อใช้จ่ายในครัวเรือน   71284.00
# 9  ภาคกลาง    สมุทรปราการ   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร   11070.68
#
#         2547      2549      2550      2552      2554      2556      2558  \
# 0  160775.93  158059.0  155396.0  207665.0  218741.4  275576.8  164705.6
# ...

# %% [markdown]
# ## Check missing value

# %%
df.isnull().sum()
# Out:
# ภาค                         0
# จังหวัด                     0
# วัตถุประสงค์ของการกู้ยืม    0
# 2545                        7
# 2547                        7
# 2549                        7
# 2550                        7
# 2552                        7
# 2554                        7
# 2556                        0
# 2558                        0
# 2560                        0
# dtype: int64

# %% [markdown]
# ## Handle with missing value

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# ภาค                         0
# จังหวัด                     0
# วัตถุประสงค์ของการกู้ยืม    0
# 2545                        0
# 2547                        0
# 2549                        0
# 2550                        0
# 2552                        0
# 2554                        0
# 2556                        0
# 2558                        0
# 2560                        0
# dtype: int64

# %%
df.sample(10)
# Out:
#                        ภาค    จังหวัด            วัตถุประสงค์ของการกู้ยืม  \
# 157                ภาคกลาง  สมุทรสาคร                  เพื่อใช้ทำการเกษตร
# 94                 ภาคกลาง       ตราด                  เพื่อใช้ทำการเกษตร
# 461                 ภาคใต้      พังงา                              อื่น ๆ
# 359  ภาคตะวันออกเฉียงเหนือ     บึงกาฬ   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร
# 401  ภาคตะวันออกเฉียงเหนือ  มหาสารคาม   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร
# 482                 ภาคใต้      ระนอง                              อื่น ๆ
# 152                ภาคกลาง     นครปฐม  เพื่อใช้ซื้อ/เช่าซื้อบ้านและที่ดิน
# 120                ภาคกลาง    สระแก้ว             เพื่อใช้จ่ายในครัวเรือน
# 377  ภาคตะวันออกเฉียงเหนือ    ขอนแก่น                              อื่น ๆ
# 488                 ภาคใต้      ชุมพร  เพื่อใช้ซื้อ/เช่าซื้อบ้านและที่ดิน
#
#          2545      2547     2549     2550     2552     2554      2556  \
# 157   8700.65   6826.01   7391.0   5986.0   7195.0   9445.5     988.9
# ...
