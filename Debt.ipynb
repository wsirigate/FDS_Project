# %% [markdown]
# # Import Libary

# %%
import pandas as pd

# %% [markdown]
# # Import Data

# %%
raw = pd.read_excel("หนี้สินเฉลี่ยต่อครัวเรือน จำแนกตามวัตถุประสงค์ของการกู้ยืม เป็นรายจังหวัด_พ.ศ._2545-2560_edit.xlsx")

# %%
raw.head(10)
# Out:
#        ภาค        จังหวัด            วัตถุประสงค์ของการกู้ยืม       2545  \
# 0  ภาคกลาง  กรุงเทพมหานคร                     หนี้สินทั้งสิ้น  162199.23
# 1  ภาคกลาง  กรุงเทพมหานคร             เพื่อใช้จ่ายในครัวเรือน  117724.88
# 2  ภาคกลาง  กรุงเทพมหานคร   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร   44118.82
# 3  ภาคกลาง  กรุงเทพมหานคร                  เพื่อใช้ทำการเกษตร      85.69
# 4  ภาคกลาง  กรุงเทพมหานคร                  เพื่อใช้ในการศึกษา       0.00
# 5  ภาคกลาง  กรุงเทพมหานคร  เพื่อใช้ซื้อ/เช่าซื้อบ้านและที่ดิน       0.00
# 6  ภาคกลาง  กรุงเทพมหานคร                              อื่น ๆ     269.82
# 7  ภาคกลาง    สมุทรปราการ                     หนี้สินทั้งสิ้น   84345.14
# 8  ภาคกลาง    สมุทรปราการ             เพื่อใช้จ่ายในครัวเรือน   71284.00
# 9  ภาคกลาง    สมุทรปราการ   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร   11070.68
#
#         2547      2549      2550      2552      2554      2556      2558  \
# 0  160775.93  158059.0  155396.0  207665.0  218741.4  275576.8  164705.6
# ...

# %% [markdown]
# # Select column

# %%
select1 = raw.iloc[:, 0:3]
select2 = raw.iloc[:, 11:12]

# %% [markdown]
# # Create key and add to column for merge

# %%
lst = []
for i in range(539):
    lst.append(i)

# %%
select1["key"] = lst
select2["key"] = lst

# %%
select1.head()
# Out:
#        ภาค        จังหวัด           วัตถุประสงค์ของการกู้ยืม  key
# 0  ภาคกลาง  กรุงเทพมหานคร                    หนี้สินทั้งสิ้น    0
# 1  ภาคกลาง  กรุงเทพมหานคร            เพื่อใช้จ่ายในครัวเรือน    1
# 2  ภาคกลาง  กรุงเทพมหานคร  เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร    2
# 3  ภาคกลาง  กรุงเทพมหานคร                 เพื่อใช้ทำการเกษตร    3
# 4  ภาคกลาง  กรุงเทพมหานคร                 เพื่อใช้ในการศึกษา    4

# %%
select2.head()
# Out:
#         2560  key
# 0  202699.85    0
# 1   65061.29    1
# 2   10537.76    2
# 3      10.80    3
# 4    2261.56    4

# %% [markdown]
# # Merge column

# %%
df = select1.merge(select2, left_on='key', right_on='key')

# %% [markdown]
# ## Delete key column

# %%
del df['key']

# %% [markdown]
# # Dept in 2560

# %%
df.head(10)
# Out:
#        ภาค        จังหวัด            วัตถุประสงค์ของการกู้ยืม       2560
# 0  ภาคกลาง  กรุงเทพมหานคร                     หนี้สินทั้งสิ้น  202699.85
# 1  ภาคกลาง  กรุงเทพมหานคร             เพื่อใช้จ่ายในครัวเรือน   65061.29
# 2  ภาคกลาง  กรุงเทพมหานคร   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร   10537.76
# 3  ภาคกลาง  กรุงเทพมหานคร                  เพื่อใช้ทำการเกษตร      10.80
# 4  ภาคกลาง  กรุงเทพมหานคร                  เพื่อใช้ในการศึกษา    2261.56
# 5  ภาคกลาง  กรุงเทพมหานคร  เพื่อใช้ซื้อ/เช่าซื้อบ้านและที่ดิน  123080.32
# 6  ภาคกลาง  กรุงเทพมหานคร                              อื่น ๆ    1748.11
# 7  ภาคกลาง    สมุทรปราการ                     หนี้สินทั้งสิ้น  179803.61
# 8  ภาคกลาง    สมุทรปราการ             เพื่อใช้จ่ายในครัวเรือน   41492.81
# 9  ภาคกลาง    สมุทรปราการ   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร    3025.70

# %%
count = 0
for i in df.index:
    num = i-count
    if df.iloc[num]["วัตถุประสงค์ของการกู้ยืม"] == "หนี้สินทั้งสิ้น":
        df = df.drop([i])
        count += 1
df.head(10)
# Out:
#         ภาค        จังหวัด            วัตถุประสงค์ของการกู้ยืม       2560
# 1   ภาคกลาง  กรุงเทพมหานคร             เพื่อใช้จ่ายในครัวเรือน   65061.29
# 2   ภาคกลาง  กรุงเทพมหานคร   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร   10537.76
# 3   ภาคกลาง  กรุงเทพมหานคร                  เพื่อใช้ทำการเกษตร      10.80
# 4   ภาคกลาง  กรุงเทพมหานคร                  เพื่อใช้ในการศึกษา    2261.56
# 5   ภาคกลาง  กรุงเทพมหานคร  เพื่อใช้ซื้อ/เช่าซื้อบ้านและที่ดิน  123080.32
# 6   ภาคกลาง  กรุงเทพมหานคร                              อื่น ๆ    1748.11
# 8   ภาคกลาง    สมุทรปราการ             เพื่อใช้จ่ายในครัวเรือน   41492.81
# 9   ภาคกลาง    สมุทรปราการ   เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร    3025.70
# 10  ภาคกลาง    สมุทรปราการ                  เพื่อใช้ทำการเกษตร     212.26
# 11  ภาคกลาง    สมุทรปราการ                  เพื่อใช้ในการศึกษา     568.94

# %% [markdown]
# # ข้อมูลหนี้สินทั้งสิ้น.

# %%
all_dept = df[df.วัตถุประสงค์ของการกู้ยืม == "หนี้สินทั้งสิ้น"]
del all_dept["วัตถุประสงค์ของการกู้ยืม"]

# %%
all_dept.sample(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-ee7e04b33629> in <module>
# ----> 1 all_dept.sample(10)
#
# ~\Miniconda3\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4863                              "provide positive value.")
#    4864
# -> 4865         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4866         return self.take(locs, axis=axis, is_copy=False)
#    4867
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: 'a' must be greater than 0 unless no samples are taken

# %%
# ALL Data

# df.head()
# all_dept.head()
#
