# %% [markdown]
# # Import Libary

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
import numpy as np

# %% [markdown]
# # Import Data

# %%
df = pd.read_excel("หนี้สินเฉลี่ยต่อครัวเรือน จำแนกตามวัตถุประสงค์ของการกู้ยืม เป็นรายจังหวัด_พ.ศ._2545-2560_edit.xlsx")

# %%
df.sample(10)
# Out:
#                        ภาค     จังหวัด           วัตถุประสงค์ของการกู้ยืม  \
# 405  ภาคตะวันออกเฉียงเหนือ   มหาสารคาม                             อื่น ๆ
# 342  ภาคตะวันออกเฉียงเหนือ       ยโสธร                             อื่น ๆ
# 136                ภาคกลาง   กาญจนบุรี                 เพื่อใช้ทำการเกษตร
# 265               ภาคเหนือ   กำแพงเพชร                             อื่น ๆ
# 43                 ภาคกลาง      ลพบุรี            เพื่อใช้จ่ายในครัวเรือน
# 300               ภาคเหนือ   เพชรบูรณ์                             อื่น ๆ
# 312  ภาคตะวันออกเฉียงเหนือ   บุรีรัมย์                 เพื่อใช้ในการศึกษา
# 58                 ภาคกลาง      ชัยนาท  เพื่อใช้ทำธุรกิจที่ไม่ใช่การเกษตร
# 146                ภาคกลาง  สุพรรณบุรี                             อื่น ๆ
# 105                ภาคกลาง  ปราจีนบุรี                    หนี้สินทั้งสิ้น
#
#          2545      2547     2549      2550      2552      2554      2556  \
# 405    546.03   3066.95   4284.0    2548.0     347.0       8.6     633.6
# ...

# %%
# df.describe()

# %%
y2545 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2545"]]
y2547 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2547"]]
y2549 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2549"]]
y2550 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2550"]]
y2552 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2552"]]
y2554 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2554"]]
y2556 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2556"]]
y2558 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2558"]]
# y2560 = df[["ภาค", "จังหวัด", "วัตถุประสงค์ของการกู้ยืม", "2560"]]
