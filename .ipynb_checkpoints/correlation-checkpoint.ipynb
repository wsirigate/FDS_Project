# %%
label <- c("2549", "2550", "2552", "2554", "2556", "2558")
debt <- c(17897.550438596492, 18571.048245614034, 21036.032894736843, 20587.189692982476, 24828.56558441559, 26057.702380952374)
debt <- round(debt,2)
gdp <- c(8400647, 9076303, 9658664, 11306907, 12921155, 13672851)

# %%
cor.test(debt, gdp)
# Out:
# 	Pearson's product-moment correlation
#
# data:  debt and gdp
# t = 6.6499, df = 4, p-value = 0.002655
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.6555076 0.9955070
# sample estimates:
#       cor
# 0.9576264

# %%
plot(gdp, debt, main="Correlation between debt and GDP", xlab="GDP", ylab="AVG DEBT", pch=16, cex.axis = 0.9)
# text(gdp, debt, gdp, cex = 0.6)
# Out:
# Plot with title "Correlation between debt and GDP"

# %%
?plot()
